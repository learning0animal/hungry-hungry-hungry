# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# %matplotlib inline

# %%
path = Path('data/record/')

# %%
count_df = pd.read_csv(path/'count.csv', names=['filename', 'count'])
count_df.head()
# Out:
#                           filename  count
# 0  data/record/20190315-111343.jpg      1
# 1  data/record/20190315-111445.jpg      1
# 2  data/record/20190315-111547.jpg      2
# 3  data/record/20190315-111650.jpg      0
# 4  data/record/20190315-111752.jpg      0

# %%
count_df.plot()
